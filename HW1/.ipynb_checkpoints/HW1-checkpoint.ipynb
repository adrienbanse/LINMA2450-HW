# %%
using JuMP, Gurobi, XLSX

# %%
xf = XLSX.readxlsx("toy-stores.xlsx")
# Out:
# XLSXFile("toy-stores.xlsx") containing 1 Worksheet
#             sheetname size          range
# -------------------------------------------------
#                Sheet1 102x12        A1:L102

# %%
data = xf["Sheet1"]
# Out:
# 102×12 XLSX.Worksheet: ["Sheet1"](A1:L102)

# %%
model = Model(with_optimizer(Gurobi.Optimizer))
M = 100
N = 24
# Out:
# Academic license - for non-commercial use only
# 24

# %%
set_optimizer_attribute(model, "Presolve", 0)
set_optimizer_attribute(model, "Heuristics", 0)
set_optimizer_attribute(model, "Cuts", 0)
# Out:
# 0

# %%
# Variables
@variable(model, 0 <= x[1:M,1:N]) # + Constraint (4)
@variable(model, 0 <= y[1:N],Bin) # + Constraint (5)
# Out:
# An object of name x is already attached to this model. If this is intended, consider using the anonymous construction syntax, e.g., x = @variable(model, [1:N], ...) where the name of the object does not appear inside the macro.
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] _error_if_cannot_register(::Model, ::Symbol) at /Users/marinebranders/.julia/packages/JuMP/qhoVb/src/macros.jl:64
#  [3] top-level scope at /Users/marinebranders/.julia/packages/JuMP/qhoVb/src/macros.jl:87
#  [4] top-level scope at In[22]:2
#  [5] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [6] execute_code(::String, ::String) at /Users/marinebranders/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/marinebranders/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [8] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [9] invokelatest at ./essentials.jl:709 [inlined]
#  [10] eventloop(::ZMQ.Socket) at /Users/marinebranders/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [11] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
# Compute costs C_ij and fixed costs f_j
C = zeros(Float64, (M,N))
f = zeros(Float64,N)
for j in 1:N
    lat2 = deg2rad(data[j+2,11])
    long2 = deg2rad(data[j+2,10])
    f[j]=data[j+2,12]
    for i in 1:M
        lat = deg2rad(data[i+2,4]) 
        long = deg2rad(data[i+2,3])
        if lat==lat2 && long ==long2 
            C[i,j]=0
        else
            C[i,j]=2*asin(sqrt( sin((lat2-lat)/2)^2 + cos(lat)*cos(lat2)*sin((long2-long)/2)^2 ))*3958.8 *data[i+2,5]
            #C[i,j]= acos(sin(lat)*sin(lat2)+cos(lat)*cos(lat2)*cos(long-long2))
        end
    end
end

# %%
# Objective function
@objective(model, Min, sum(C .* x) + sum(f .* y))
# Out:
# 9.945386429637533e6 x[1,1] + 1.0916440001080781e7 x[3,1] + 1.529713000471215e7 x[4,1] + 2.8584887753416053e6 x[5,1] + 7.636521417379292e6 x[6,1] + 5.719058723359763e6 x[7,1] + 4.2088440734258115e7 x[8,1] + 9.30615403999812e6 x[9,1] + 5.10685747007257e6 x[10,1] + 4.0490804487175584e7 x[11,1] + 7.826941172766576e6 x[12,1] + 1.738843354926437e7 x[13,1] + 1.9901036338442277e7 x[14,1] + 7.936849835771717e6 x[15,1] + 8.540213115409872e7 x[16,1] + 1.570651967564273e7 x[17,1] + 2.4488142996159937e7 x[18,1] + 3.194866646230881e6 x[19,1] + 1.2328849531384233e7 x[20,1] + 7.334404450811219e6 x[21,1] + 7.617069791690432e6 x[22,1] + 6.967495242111729e6 x[23,1] + 4.718677991244333e6 x[24,1] + 6.001098097342096e6 x[25,1] + 1.0140859850633493e7 x[26,1] + 7.1681493103836775e6 x[27,1] + 4.04820894661242e6 x[28,1] + 3.1107184843962104e6 x[29,1] + 7.42899415583295e6 x[30,1] + 9.95130375095974e6 x[31,1] + 6.614547456944196e6 x[32,1] + 7.648822610608423e6 x[33,1] + 7.735959017487958e6 x[34,1] + 8.065440067773436e6 x[35,1] + 3.3909172767047904e7 x[36,1] + 5.750088805184786e6 x[37,1] + 5.28107471725859e6 x[38,1] + 2.9245457460479386e7 x[39,1] + 2.0043302450604732e6 x[40,1] + 4.678248697003943e6 x[41,1] + 2.727192043820963e6 x[42,1] + 9.402618544966869e6 x[43,1] + 6.58474342954876e6 x[44,1] + 5.283011048124014e6 x[45,1] + 1.5962538788601116e6 x[46,1] + 6.918454187554856e6 x[47,1] + 3.872905451647426e6 x[48,1] + 1.1128318481951835e7 x[49,1] + 6.842894638829919e6 x[50,1] + 1.670737280397805e7 x[51,1] + 5.850388615652002e6 x[52,1] + 4.723417418780557e6 x[53,1] + 1.911606334734175e7 x[54,1] + 1.4127094737543274e7 x[55,1] + 6.903602955354194e6 x[56,1] + 7.772266519447793e6 x[57,1] + 1.5466654769874992e7 x[58,1] + 1.4609569313661635e7 x[59,1] + 1.225826549398978e7 x[60,1] + 1.6791461562682375e7 x[61,1] + 4.548894500005749e6 x[62,1] + 3.7462371543120756e6 x[63,1] + 8.42403750474807e6 x[64,1] + 3.9136471894185385e6 x[65,1] + 4.595190040648958e6 x[66,1] + 2.2630954883514605e6 x[67,1] + 6.755065166154002e6 x[68,1] + 2.4120661731836744e7 x[69,1] + 3.0609652651589415e6 x[70,1] + 2.6281988728776835e7 x[71,1] + 1.0185948496875424e7 x[72,1] + 5.592689403284749e6 x[73,1] + 1.1771742177251397e7 x[74,1] + 6.838063543650494e6 x[75,1] + 1.1931373370919753e7 x[76,1] + 1.5050950790042417e7 x[77,1] + 4.292888889008957e6 x[78,1] + 1.4334337478742376e7 x[79,1] + 3.491173942696441e7 x[80,1] + 3.0092979526932728e7 x[81,1] + 7.231647189049417e6 x[82,1] + 5.731386232683755e6 x[83,1] + 8.649123838670896e6 x[84,1] + 9.940422503145153e6 x[85,1] + 2.567415688778608e6 x[86,1] + 1.0312553780850453e7 x[87,1] + 9.684219655485196e6 x[88,1] + 1.2235945878860082e7 x[89,1] + 1.023871088498822e7 x[90,1] + 5.21486300563807e6 x[91,1] + 1.5512966162079163e7 x[92,1] + 1.985897565067341e6 x[93,1] + 4.865475876556032e6 x[94,1] + 9.955613711297829e6 x[95,1] + 4.779479133761174e6 x[96,1] + 1.9806106950382225e7 x[97,1] + 6.378968817938381e6 x[98,1] + 3.529594502671683e7 x[99,1] + 1.1872786085404642e7 x[100,1] + 9.952717564299004e6 x[1,2] + 2.432278711091567e6 x[2,2] + 1.0355873001076212e7 x[3,2] + 1.2546977202415423e7 x[4,2] + 6.206691428641082e6 x[5,2] + 7.558025177883106e6 x[7,2] + 4.017959186446957e7 x[8,2] + 7.320930282985034e6 x[9,2] + 7.262748220750704e6 x[10,2] + 3.9876873892470725e7 x[11,2] + 7.634793544775936e6 x[12,2] + 1.7649191944981076e7 x[13,2] + 1.7466361236809723e7 x[14,2] + 7.278744679482112e6 x[15,2] + 9.349825093024568e7 x[16,2] + 1.5347997909461726e7 x[17,2] + 2.4718454602673266e7 x[18,2] + 7.579679293482135e6 x[19,2] + 6.700320482192135e6 x[20,2] + 7.273665713048467e6 x[21,2] + 1.6372709468203612e7 x[22,2] + 6.266579851885636e6 x[23,2] + 4.567237718375876e6 x[24,2] + 6.340363869641477e6 x[25,2] + 7.8729793764021145e6 x[26,2] + 7.412862968922754e6 x[27,2] + 5.2853055239033075e6 x[28,2] + 4.526374825970941e6 x[29,2] + 8.035358283300193e6 x[30,2] + 8.940152244658183e6 x[31,2] + 6.100754610743946e6 x[32,2] + 7.505035147138576e6 x[33,2] + 5.9835786462329645e6 x[34,2] + 6.255981886844899 ...

# %%
# Constraint (2)
@constraint(model, sum(x, dims=2) .== ones(Float64, M))
# Out:
# 100×1 Array{ConstraintRef{Model,MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64},MathOptInterface.EqualTo{Float64}},ScalarShape},2}:
#  x[1,1] + x[1,2] + x[1,3] + x[1,4] + x[1,5] + x[1,6] + x[1,7] + x[1,8] + x[1,9] + x[1,10] + x[1,11] + x[1,12] + x[1,13] + x[1,14] + x[1,15] + x[1,16] + x[1,17] + x[1,18] + x[1,19] + x[1,20] + x[1,21] + x[1,22] + x[1,23] + x[1,24] = 1.0
#  x[2,1] + x[2,2] + x[2,3] + x[2,4] + x[2,5] + x[2,6] + x[2,7] + x[2,8] + x[2,9] + x[2,10] + x[2,11] + x[2,12] + x[2,13] + x[2,14] + x[2,15] + x[2,16] + x[2,17] + x[2,18] + x[2,19] + x[2,20] + x[2,21] + x[2,22] + x[2,23] + x[2,24] = 1.0
#  x[3,1] + x[3,2] + x[3,3] + x[3,4] + x[3,5] + x[3,6] + x[3,7] + x[3,8] + x[3,9] + x[3,10] + x[3,11] + x[3,12] + x[3,13] + x[3,14] + x[3,15] + x[3,16] + x[3,17] + x[3,18] + x[3,19] + x[3,20] + x[3,21] + x[3,22] + x[3,23] + x[3,24] = 1.0
#  x[4,1] + x[4,2] + x[4,3] + x[4,4] + x[4,5] + x[4,6] + x[4,7] + x[4,8] + x[4,9] + x[4,10] + x[4,11] + x[4,12] + x[4,13] + x[4,14] + x[4,15] + x[4,16] + x[4,17] + x[4,18] + x[4,19] + x[4,20] + x[4,21] + x[4,22] + x[4,23] + x[4,24] = 1.0
#  x[5,1] + x[5,2] + x[5,3] + x[5,4] + x[5,5] + x[5,6] + x[5,7] + x[5,8] + x[5,9] + x[5,10] + x[5,11] + x[5,12] + x[5,13] + x[5,14] + x[5,15] + x[5,16] + x[5,17] + x[5,18] + x[5,19] + x[5,20] + x[5,21] + x[5,22] + x[5,23] + x[5,24] = 1.0
#  x[6,1] + x[6,2] + x[6,3] + x[6,4] + x[6,5] + x[6,6] + x[6,7] + x[6,8] + x[6,9] + x[6,10] + x[6,11] + x[6,12] + x[6,13] + x[6,14] + x[6,15] + x[6,16] + x[6,17] + x[6,18] + x[6,19] + x[6,20] + x[6,21] + x[6,22] + x[6,23] + x[6,24] = 1.0
#  x[7,1] + x[7,2] + x[7,3] + x[7,4] + x[7,5] + x[7,6] + x[7,7] + x[7,8] + x[7,9] + x[7,10] + x[7,11] + x[7,12] + x[7,13] + x[7,14] + x[7,15] + x[7,16] + x[7,17] + x[7,18] + x[7,19] + x[7,20] + x[7,21] + x[7,22] + x[7,23] + x[7,24] = 1.0
#  x[8,1] + x[8,2] + x[8,3] + x[8,4] + x[8,5] + x[8,6] + x[8,7] + x[8,8] + x[8,9] + x[8,10] + x[8,11] + x[8,12] + x[8,13] + x[8,14] + x[8,15] + x[8,16] + x[8,17] + x[8,18] + x[8,19] + x[8,20] + x[8,21] + x[8,22] + x[8,23] + x[8,24] = 1.0
#  x[9,1] + x[9,2] + x[9,3] + x[9,4] + x[9,5] + x[9,6] + x[9,7] + x[9,8] + x[9,9] + x[9,10] + x[9,11] + x[9,12] + x[9,13] + x[9,14] + x[9,15] + x[9,16] + x[9,17] + x[9,18] + x[9,19] + x[9,20] + x[9,21] + x[9,22] + x[9,23] + x[9,24] = 1.0
#  x[10,1] + x[10,2] + x[10,3] + x[10,4] + x[10,5] + x[10,6] + x[10,7] + x[10,8] + x[10,9] + x[10,10] + x[10,11] + x[10,12] + x[10,13] + x[10,14] + x[10,15] + x[10,16] + x[10,17] + x[10,18] + x[10,19] + x[10,20] + x[10,21] + x[10,22] + x[10,23] + x[10,24] = 1.0
#  x[11,1] + x[11,2] + x[11,3] + x[11,4] + x[11,5] + x[11,6] + x[11,7] + x[11,8] + x[11,9] + x[11,10] + x[11,11] + x[11,12] + x[11,13] + x[11,14] + x[11,15] + x[11,16] + x[11,17] + x[11,18] + x[11,19] + x[11,20] + x[11,21] + x[11,22] + x[11,23] + x[11,24] = 1.0
#  x[12,1] + x[12,2] + x[12,3] + x[12,4] + x[12,5] + x[12,6] + x[12,7] + x[12,8] + x[12,9] + x[12,10] + x[12,11] + x[12,12] + x[12,13] + x[12,14] + x[12,15] + x[12,16] + x[12,17] + x[12,18] + x[12,19] + x[12,20] + x[12,21] + x[12,22] + x[12,23] + x[12,24] = 1.0
#  x[13,1] + x[13,2] + x[13,3] + x[13,4] + x[13,5] + x[13,6] + x[13,7] + x[13,8] + x[13,9] + x[13,10] + x[13,11] + x[13,12] + x[13,13] + x[13,14] + x[13,15] + x[13,16] + x[13,17] + x[13,18] + x[13,19] + x[13,20] + x[13,21] + x[13,22] + x[13,23] + x[13,24] = 1.0
#  ⋮
#  x[89,1] + x[89,2] + x[89,3] + x[89,4] + x[89,5] + x[89,6] + x[89,7] + x[89,8] + x[89,9] + x[89,10] + x[89,11] + x[89,12] + x[89,13] + x[89,14] + x[89,15] + x[89,16] + x[89,17] + x[89,18] + x[89,19] + x[89,20] + x[89,21] + x[89,22] + x[89,23] + x[89,24] = 1.0
#  x[90,1] + x[90,2] + x[90,3] + x[90,4] + x[90,5] + x[90,6] + x[90,7] + x[90,8] + x[90,9] + x[90,10] + x[90,11] + x[90,12] + x[90,13] + x[90,14] + x[90,15] + x[90,16] + x[90,17] + x[90,18] + x[90,19] + x[90,20] + x[90,21] + x[90,22] + x[90,23] + x[90,24] = 1.0
#  x[91,1] + x[91,2] + x[91,3] + x[91,4] + x[91,5] + x[91,6] + x[91,7] + x[91,8] + x[91,9] + x[91,10] + x[91,11] + x[91,12] + x[91,13] + x[91,14] + x[91,15] + x[91,16] + x[91,17] + x[91,18] + x[91,19] + x[91,20] + x[91,21] + x[91,22] + x[91,23] + x[91,24] = 1.0
#  x[92,1] + x[92,2] + x[92,3] + x[92,4] + x[92,5] + x[92,6] + x[92,7] + x[92,8] + x[92,9] + x[92,10] + x[92,11] + x[92,12] + x[92,13] + x[92,14] + x[92,15] + x[92,16] + x[92,17] + x[92,18] + x[92,19] + x[92,20] + x[92,21] + x[92,22] + x[92,23] + x[92,24] = 1.0
#  x[93,1] + x[93,2] + x[93,3] + x[93,4] + x[93,5] + x[93,6] + x[93,7] + x[93,8] + x[93,9] + x[93,10] + x[93,11] + x[93,12] + x[93,13] + x[93,14] + x[93,15] + x[93,16] + x[93,17] + x[93,18] + x[93,19] + x[93,20] + x[93,21] + x[93,22] + x[93,23] + x[93,24] = 1.0
#  x[94,1] + x[94,2] + x[94,3] + x[94,4] + x[94,5] + x[94,6] + x[94,7] + x[94,8] + x[94,9] + x[94,10] + x[94,11] + x[94,12] + x[94,13] + x[94,14] + x[94,15] + x[94,16] + x[94,17] + x[94,18] + x[94,19] + x[94,20] + x[94,21] + x[94,22] + x[94,23] + x[94,24] = 1.0
#  x[95,1] + x[95,2] + x[95,3] + x[95,4] + x[95,5] + x[95,6] + x[95,7] + x[95,8] + x[95,9] + x[95,10] + x[95,11] + x[95,12] + x[95,13] + x[95,14] + x[95,15] + x[95,16] + x[95,17] + x[95,18] + x[95,19] + x[95,20] + x[95,21] + x[95,22] + x[95,23] + x[95,24] = 1.0
#  x[96,1] + x[96,2] + x[96,3] + x[96,4] + x[96,5] + x[96,6] + x[96,7] + x[96,8] + x[96,9] + x[96,10] + x[96,11] + x[96,12] + x[96,13] + x[96,14] + x[96,15] + x[96,16] + x[96,17] + x[96,18] + x[96,19] + x[96,20] + x[96,21] + x[96,22] + x[96,23] + x[96,24] = 1.0
#  x[97,1] + x[97,2] + x[97,3] + x[97,4] + x[97,5] + x[97,6] + x[97,7] + x[97,8] + x[97,9] + x[97,10] + x[97,11] + x[97,12] + x[97,13] + x[97,14] + x[97,15] + x[97,16] + x[97,17] + x[97,18] + x[97,19] + x[97,20] + x[97,21] + x[97,22] + x[97,23] + x[97,24] = 1.0
#  x[98,1] + x[98,2] + x[98,3] + x[98,4] + x[98,5] + x[98,6] + x[98,7] + x[98,8] + x[98,9] + x[98,10] + x[98,11] + x[98,12] + x[98,13] + x[98,14] + x[98,15] + x[98,16] + x[98,17] + x[98,18] + x[98,19] + x[98,20] + x[98,21] + x[98,22] + x[98,23] + x[98,24] = 1.0
#  x[99,1] + x[99,2] + x[99,3] + x[99,4] + x[99,5] + x[99,6] + x[99,7] + x[99,8] + x[99,9] + x[99,10] + x[99,11] + x[99,12] + x[99,13] + x[99,14] + x[99,15] + x[99,16] + x[99,17] + x[99,18] + x[99,19] + x[99,20] + x[99,21] + x[99,22] + x[99,23] + x[99,24] = 1.0
#  x[100,1] + x[100,2] + x[100,3] + x[100,4] + x[100,5] + x[100,6] + x[100,7] + x[100,8] + x[100,9] + x[100,10] + x[100,11] + x[100,12] + x[100,13] + x[100,14] + x[100,15] + x[100,16] + x[100,17] + x[100,18] + x[100,19] + x[100,20] + x[100,21] + x[100,22] + x[100,23] + x[100,24] = 1.0

# %%
# Constraint (3)
@constraint(model, [i = 1:M], x[i,:] .<= y)
# Out:
# 100-element Array{Array{ConstraintRef{Model,MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64},MathOptInterface.LessThan{Float64}},ScalarShape},1},1}:
#  [x[1,1] - y[1] ≤ 0.0, x[1,2] - y[2] ≤ 0.0, x[1,3] - y[3] ≤ 0.0, x[1,4] - y[4] ≤ 0.0, x[1,5] - y[5] ≤ 0.0, x[1,6] - y[6] ≤ 0.0, x[1,7] - y[7] ≤ 0.0, x[1,8] - y[8] ≤ 0.0, x[1,9] - y[9] ≤ 0.0, x[1,10] - y[10] ≤ 0.0  …  x[1,15] - y[15] ≤ 0.0, x[1,16] - y[16] ≤ 0.0, x[1,17] - y[17] ≤ 0.0, x[1,18] - y[18] ≤ 0.0, x[1,19] - y[19] ≤ 0.0, x[1,20] - y[20] ≤ 0.0, x[1,21] - y[21] ≤ 0.0, x[1,22] - y[22] ≤ 0.0, x[1,23] - y[23] ≤ 0.0, x[1,24] - y[24] ≤ 0.0]
#  [x[2,1] - y[1] ≤ 0.0, x[2,2] - y[2] ≤ 0.0, x[2,3] - y[3] ≤ 0.0, x[2,4] - y[4] ≤ 0.0, x[2,5] - y[5] ≤ 0.0, x[2,6] - y[6] ≤ 0.0, x[2,7] - y[7] ≤ 0.0, x[2,8] - y[8] ≤ 0.0, x[2,9] - y[9] ≤ 0.0, x[2,10] - y[10] ≤ 0.0  …  x[2,15] - y[15] ≤ 0.0, x[2,16] - y[16] ≤ 0.0, x[2,17] - y[17] ≤ 0.0, x[2,18] - y[18] ≤ 0.0, x[2,19] - y[19] ≤ 0.0, x[2,20] - y[20] ≤ 0.0, x[2,21] - y[21] ≤ 0.0, x[2,22] - y[22] ≤ 0.0, x[2,23] - y[23] ≤ 0.0, x[2,24] - y[24] ≤ 0.0]
#  [x[3,1] - y[1] ≤ 0.0, x[3,2] - y[2] ≤ 0.0, x[3,3] - y[3] ≤ 0.0, x[3,4] - y[4] ≤ 0.0, x[3,5] - y[5] ≤ 0.0, x[3,6] - y[6] ≤ 0.0, x[3,7] - y[7] ≤ 0.0, x[3,8] - y[8] ≤ 0.0, x[3,9] - y[9] ≤ 0.0, x[3,10] - y[10] ≤ 0.0  …  x[3,15] - y[15] ≤ 0.0, x[3,16] - y[16] ≤ 0.0, x[3,17] - y[17] ≤ 0.0, x[3,18] - y[18] ≤ 0.0, x[3,19] - y[19] ≤ 0.0, x[3,20] - y[20] ≤ 0.0, x[3,21] - y[21] ≤ 0.0, x[3,22] - y[22] ≤ 0.0, x[3,23] - y[23] ≤ 0.0, x[3,24] - y[24] ≤ 0.0]
#  [x[4,1] - y[1] ≤ 0.0, x[4,2] - y[2] ≤ 0.0, x[4,3] - y[3] ≤ 0.0, x[4,4] - y[4] ≤ 0.0, x[4,5] - y[5] ≤ 0.0, x[4,6] - y[6] ≤ 0.0, x[4,7] - y[7] ≤ 0.0, x[4,8] - y[8] ≤ 0.0, x[4,9] - y[9] ≤ 0.0, x[4,10] - y[10] ≤ 0.0  …  x[4,15] - y[15] ≤ 0.0, x[4,16] - y[16] ≤ 0.0, x[4,17] - y[17] ≤ 0.0, x[4,18] - y[18] ≤ 0.0, x[4,19] - y[19] ≤ 0.0, x[4,20] - y[20] ≤ 0.0, x[4,21] - y[21] ≤ 0.0, x[4,22] - y[22] ≤ 0.0, x[4,23] - y[23] ≤ 0.0, x[4,24] - y[24] ≤ 0.0]
#  [x[5,1] - y[1] ≤ 0.0, x[5,2] - y[2] ≤ 0.0, x[5,3] - y[3] ≤ 0.0, x[5,4] - y[4] ≤ 0.0, x[5,5] - y[5] ≤ 0.0, x[5,6] - y[6] ≤ 0.0, x[5,7] - y[7] ≤ 0.0, x[5,8] - y[8] ≤ 0.0, x[5,9] - y[9] ≤ 0.0, x[5,10] - y[10] ≤ 0.0  …  x[5,15] - y[15] ≤ 0.0, x[5,16] - y[16] ≤ 0.0, x[5,17] - y[17] ≤ 0.0, x[5,18] - y[18] ≤ 0.0, x[5,19] - y[19] ≤ 0.0, x[5,20] - y[20] ≤ 0.0, x[5,21] - y[21] ≤ 0.0, x[5,22] - y[22] ≤ 0.0, x[5,23] - y[23] ≤ 0.0, x[5,24] - y[24] ≤ 0.0]
#  [x[6,1] - y[1] ≤ 0.0, x[6,2] - y[2] ≤ 0.0, x[6,3] - y[3] ≤ 0.0, x[6,4] - y[4] ≤ 0.0, x[6,5] - y[5] ≤ 0.0, x[6,6] - y[6] ≤ 0.0, x[6,7] - y[7] ≤ 0.0, x[6,8] - y[8] ≤ 0.0, x[6,9] - y[9] ≤ 0.0, x[6,10] - y[10] ≤ 0.0  …  x[6,15] - y[15] ≤ 0.0, x[6,16] - y[16] ≤ 0.0, x[6,17] - y[17] ≤ 0.0, x[6,18] - y[18] ≤ 0.0, x[6,19] - y[19] ≤ 0.0, x[6,20] - y[20] ≤ 0.0, x[6,21] - y[21] ≤ 0.0, x[6,22] - y[22] ≤ 0.0, x[6,23] - y[23] ≤ 0.0, x[6,24] - y[24] ≤ 0.0]
#  [x[7,1] - y[1] ≤ 0.0, x[7,2] - y[2] ≤ 0.0, x[7,3] - y[3] ≤ 0.0, x[7,4] - y[4] ≤ 0.0, x[7,5] - y[5] ≤ 0.0, x[7,6] - y[6] ≤ 0.0, x[7,7] - y[7] ≤ 0.0, x[7,8] - y[8] ≤ 0.0, x[7,9] - y[9] ≤ 0.0, x[7,10] - y[10] ≤ 0.0  …  x[7,15] - y[15] ≤ 0.0, x[7,16] - y[16] ≤ 0.0, x[7,17] - y[17] ≤ 0.0, x[7,18] - y[18] ≤ 0.0, x[7,19] - y[19] ≤ 0.0, x[7,20] - y[20] ≤ 0.0, x[7,21] - y[21] ≤ 0.0, x[7,22] - y[22] ≤ 0.0, x[7,23] - y[23] ≤ 0.0, x[7,24] - y[24] ≤ 0.0]
#  [x[8,1] - y[1] ≤ 0.0, x[8,2] - y[2] ≤ 0.0, x[8,3] - y[3] ≤ 0.0, x[8,4] - y[4] ≤ 0.0, x[8,5] - y[5] ≤ 0.0, x[8,6] - y[6] ≤ 0.0, x[8,7] - y[7] ≤ 0.0, x[8,8] - y[8] ≤ 0.0, x[8,9] - y[9] ≤ 0.0, x[8,10] - y[10] ≤ 0.0  …  x[8,15] - y[15] ≤ 0.0, x[8,16] - y[16] ≤ 0.0, x[8,17] - y[17] ≤ 0.0, x[8,18] - y[18] ≤ 0.0, x[8,19] - y[19] ≤ 0.0, x[8,20] - y[20] ≤ 0.0, x[8,21] - y[21] ≤ 0.0, x[8,22] - y[22] ≤ 0.0, x[8,23] - y[23] ≤ 0.0, x[8,24] - y[24] ≤ 0.0]
#  [x[9,1] - y[1] ≤ 0.0, x[9,2] - y[2] ≤ 0.0, x[9,3] - y[3] ≤ 0.0, x[9,4] - y[4] ≤ 0.0, x[9,5] - y[5] ≤ 0.0, x[9,6] - y[6] ≤ 0.0, x[9,7] - y[7] ≤ 0.0, x[9,8] - y[8] ≤ 0.0, x[9,9] - y[9] ≤ 0.0, x[9,10] - y[10] ≤ 0.0  …  x[9,15] - y[15] ≤ 0.0, x[9,16] - y[16] ≤ 0.0, x[9,17] - y[17] ≤ 0.0, x[9,18] - y[18] ≤ 0.0, x[9,19] - y[19] ≤ 0.0, x[9,20] - y[20] ≤ 0.0, x[9,21] - y[21] ≤ 0.0, x[9,22] - y[22] ≤ 0.0, x[9,23] - y[23] ≤ 0.0, x[9,24] - y[24] ≤ 0.0]
#  [x[10,1] - y[1] ≤ 0.0, x[10,2] - y[2] ≤ 0.0, x[10,3] - y[3] ≤ 0.0, x[10,4] - y[4] ≤ 0.0, x[10,5] - y[5] ≤ 0.0, x[10,6] - y[6] ≤ 0.0, x[10,7] - y[7] ≤ 0.0, x[10,8] - y[8] ≤ 0.0, x[10,9] - y[9] ≤ 0.0, x[10,10] - y[10] ≤ 0.0  …  x[10,15] - y[15] ≤ 0.0, x[10,16] - y[16] ≤ 0.0, x[10,17] - y[17] ≤ 0.0, x[10,18] - y[18] ≤ 0.0, x[10,19] - y[19] ≤ 0.0, x[10,20] - y[20] ≤ 0.0, x[10,21] - y[21] ≤ 0.0, x[10,22] - y[22] ≤ 0.0, x[10,23] - y[23] ≤ 0.0, x[10,24] - y[24] ≤ 0.0]
#  [x[11,1] - y[1] ≤ 0.0, x[11,2] - y[2] ≤ 0.0, x[11,3] - y[3] ≤ 0.0, x[11,4] - y[4] ≤ 0.0, x[11,5] - y[5] ≤ 0.0, x[11,6] - y[6] ≤ 0.0, x[11,7] - y[7] ≤ 0.0, x[11,8] - y[8] ≤ 0.0, x[11,9] - y[9] ≤ 0.0, x[11,10] - y[10] ≤ 0.0  …  x[11,15] - y[15] ≤ 0.0, x[11,16] - y[16] ≤ 0.0, x[11,17] - y[17] ≤ 0.0, x[11,18] - y[18] ≤ 0.0, x[11,19] - y[19] ≤ 0.0, x[11,20] - y[20] ≤ 0.0, x[11,21] - y[21] ≤ 0.0, x[11,22] - y[22] ≤ 0.0, x[11,23] - y[23] ≤ 0.0, x[11,24] - y[24] ≤ 0.0]
#  [x[12,1] - y[1] ≤ 0.0, x[12,2] - y[2] ≤ 0.0, x[12,3] - y[3] ≤ 0.0, x[12,4] - y[4] ≤ 0.0, x[12,5] - y[5] ≤ 0.0, x[12,6] - y[6] ≤ 0.0, x[12,7] - y[7] ≤ 0.0, x[12,8] - y[8] ≤ 0.0, x[12,9] - y[9] ≤ 0.0, x[12,10] - y[10] ≤ 0.0  …  x[12,15] - y[15] ≤ 0.0, x[12,16] - y[16] ≤ 0.0, x[12,17] - y[17] ≤ 0.0, x[12,18] - y[18] ≤ 0.0, x[12,19] - y[19] ≤ 0.0, x[12,20] - y[20] ≤ 0.0, x[12,21] - y[21] ≤ 0.0, x[12,22] - y[22] ≤ 0.0, x[12,23] - y[23] ≤ 0.0, x[12,24] - y[24] ≤ 0.0]
#  [x[13,1] - y[1] ≤ 0.0, x[13,2] - y[2] ≤ 0.0, x[13,3] - y[3] ≤ 0.0, x[13,4] - y[4] ≤ 0.0, x[13,5] - y[5] ≤ 0.0, x[13,6] - y[6] ≤ 0.0, x[13,7] - y[7] ≤ 0.0, x[13,8] - y[8] ≤ 0.0, x[13,9] - y[9] ≤ 0.0, x[13,10] - y[10] ≤ 0.0  …  x[13,15] - y[15] ≤ 0.0, x[13,16] - y[16] ≤ 0.0, x[13,17] - y[17] ≤ 0.0, x[13,18] - y[18] ≤ 0.0, x[13,19] - y[19] ≤ 0.0, x[13,20] - y[20] ≤ 0.0, x[13,21] - y[21] ≤ 0.0, x[13,22] - y[22] ≤ 0.0, x[13,23] - y[23] ≤ 0.0, x[13,24] - y[24] ≤ 0.0]
#  ⋮
#  [x[89,1] - y[1] ≤ 0.0, x[89,2] - y[2] ≤ 0.0, x[89,3] - y[3] ≤ 0.0, x[89,4] - y[4] ≤ 0.0, x[89,5] - y[5] ≤ 0.0, x[89,6] - y[6] ≤ 0.0, x[89,7] - y[7] ≤ 0.0, x[89,8] - y[8] ≤ 0.0, x[89,9] - y[9] ≤ 0.0, x[89,10] - y[10] ≤ 0.0  …  x[89,15] - y[15] ≤ 0.0, x[89,16] - y[16] ≤ 0.0, x[89,17] - y[17] ≤ 0.0, x[89,18] - y[18] ≤ 0.0, x[89,19] - y[19] ≤ 0.0, x[89,20] - y[20] ≤ 0.0, x[89,21] - y[21] ≤ 0.0, x[89,22] - y[22] ≤ 0.0, x[89,23] - y[23] ≤ 0.0, x[89,24] - y[24] ≤ 0.0]
#  [x[90,1] - y[1] ≤ 0.0, x[90,2] - y[2] ≤ 0.0, x[90,3] - y[3] ≤ 0.0, x[90,4] - y[4] ≤ 0.0, x[90,5] - y[5] ≤ 0.0, x[90,6] - y[6] ≤ 0.0, x[90,7] - y[7] ≤ 0.0, x[90,8] - y[8] ≤ 0.0, x[90,9] - y[9] ≤ 0.0, x[90,10] - y[10] ≤ 0.0  …  x[90,15] - y[15] ≤ 0.0, x[90,16] - y[16] ≤ 0.0, x[90,17] - y[17] ≤ 0.0, x[90,18] - y[18] ≤ 0.0, x[90,19] - y[19] ≤ 0.0, x[90,20] - y[20] ≤ 0.0, x[90,21] - y[21] ≤ 0.0, x[90,22] - y[22] ≤ 0.0, x[90,23] - y[23] ≤ 0.0, x[90,24] - y[24] ≤ 0.0]
#  [x[91,1] - y[1] ≤ 0.0, x[91,2] - y[2] ≤ 0.0, x[91,3] - y[3] ≤ 0.0, x[91,4] - y[4] ≤ 0.0, x[91,5] - y[5] ≤ 0.0, x[91,6] - y[6] ≤ 0.0, x[91,7] - y[7] ≤ 0.0, x[91,8] - y[8] ≤ 0.0, x[91,9] - y[9] ≤ 0.0, x[91,10] - y[10] ≤ 0.0  …  x[91,15] - y[15] ≤ 0.0, x[91,16] - y[16] ≤ 0.0, x[91,17] - y[17] ≤ 0.0, x[91,18] - y[18] ≤ 0.0, x[91,19] - y[19] ≤ 0.0, x[91,20] - y[20] ≤ 0.0, x[91,21] - y[21] ≤ 0.0, x[91,22] - y[22] ≤ 0.0, x[91,23] - y[23] ≤ 0.0, x[91,24] - y[24] ≤ 0.0]
#  [x[92,1] - y[1] ≤ 0.0, x[92,2] - y[2] ≤ 0.0, x[92,3] - y[3] ≤ 0.0, x[92,4] - y[4] ≤ 0.0, x[92,5] - y[5] ≤ 0.0, x[92,6] - y[6] ≤ 0.0, x[92,7] - y[7] ≤ 0.0, x[92,8] - y[8] ≤ 0.0, x[92,9] - y[9] ≤ 0.0, x[92,10] - y[10] ≤ 0.0  …  x[92,15] - y[15] ≤ 0.0, x[92,16] - y[16] ≤ 0.0, x[92,17] - y[17] ≤ 0.0, x[92,18] - y[18] ≤ 0.0, x[92,19] - y[19] ≤ 0.0, x[92,20] - y[20] ≤ 0.0, x[92,21] - y[21] ≤ 0.0, x[92,22] - y[22] ≤ 0.0, x[92,23] - y[23] ≤ 0.0, x[92,24] - y[24] ≤ 0.0]
#  [x[93,1] - y[1] ≤ 0.0, x[93,2] - y[2] ≤ 0.0, x[93,3] - y[3] ≤ 0.0, x[93,4] - y[4] ≤ 0.0, x[93,5] - y[5] ≤ 0.0, x[93,6] - y[6] ≤ 0.0, x[93,7] - y[7] ≤ 0.0, x[93,8] - y[8] ≤ 0.0, x[93,9] - y[9] ≤ 0.0, x[93,10] - y[10] ≤ 0.0  …  x[93,15] - y[15] ≤ 0.0, x[93,16] - y[16] ≤ 0.0, x[93,17] - y[17] ≤ 0.0, x[93,18] - y[18] ≤ 0.0, x[93,19] - y[19] ≤ 0.0, x[93,20] - y[20] ≤ 0.0, x[93,21] - y[21] ≤ 0.0, x[93,22] - y[22] ≤ 0.0, x[93,23] - y[23] ≤ 0.0, x[93,24] - y[24] ≤ 0.0]
#  [x[94,1] - y[1] ≤ 0.0, x[94,2] - y[2] ≤ 0.0, x[94,3] - y[3] ≤ 0.0, x[94,4] - y[4] ≤ 0.0, x[94,5] - y[5] ≤ 0.0, x[94,6] - y[6] ≤ 0.0, x[94,7] - y[7] ≤ 0.0, x[94,8] - y[8] ≤ 0.0, x[94,9] - y[9] ≤ 0.0, x[94,10] - y[10] ≤ 0.0  …  x[94,15] - y[15] ≤ 0.0, x[94,16] - y[16] ≤ 0.0, x[94,17] - y[17] ≤ 0.0, x[94,18] - y[18] ≤ 0.0, x[94,19] - y[19] ≤ 0.0, x[94,20] - y[20] ≤ 0.0, x[94,21] - y[21] ≤ 0.0, x[94,22] - y[22] ≤ 0.0, x[94,23] - y[23] ≤ 0.0, x[94,24] - y[24] ≤ 0.0]
#  [x[95,1] - y[1] ≤ 0.0, x[95,2] - y[2] ≤ 0.0, x[95,3] - y[3] ≤ 0.0, x[95,4] - y[4] ≤ 0.0, x[95,5] - y[5] ≤ 0.0, x[95,6] - y[6] ≤ 0.0, x[95,7] - y[7] ≤ 0.0, x[95,8] - y[8] ≤ 0.0, x[95,9] - y[9] ≤ 0.0, x[95,10] - y[10] ≤ 0.0  …  x[95,15] - y[15] ≤ 0.0, x[95,16] - y[16] ≤ 0.0, x[95,17] - y[17] ≤ 0.0, x[95,18] - y[18] ≤ 0.0, x[95,19] - y[19] ≤ 0.0, x[95,20] - y[20] ≤ 0.0, x[95,21] - y[21] ≤ 0.0, x[95,22] - y[22] ≤ 0.0, x[95,23] - y[23] ≤ 0.0, x[95,24] - y[24] ≤ 0.0]
#  [x[96,1] - y[1] ≤ 0.0, x[96,2] - y[2] ≤ 0.0, x[96,3] - y[3] ≤ 0.0, x[96,4] - y[4] ≤ 0.0, x[96,5] - y[5] ≤ 0.0, x[96,6] - y[6] ≤ 0.0, x[96,7] - y[7] ≤ 0.0, x[96,8] - y[8] ≤ 0.0, x[96,9] - y[9] ≤ 0.0, x[96,10] - y[10] ≤ 0.0  …  x[96,15] - y[15] ≤ 0.0, x[96,16] - y[16] ≤ 0.0, x[96,17] - y[17] ≤ 0.0, x[96,18] - y[18] ≤ 0.0, x[96,19] - y[19] ≤ 0.0, x[96,20] - y[20] ≤ 0.0, x[96,21] - y[21] ≤ 0.0, x[96,22] - y[22] ≤ 0.0, x[96,23] - y[23] ≤ 0.0, x[96,24] - y[24] ≤ 0.0]
#  [x[97,1] - y[1] ≤ 0.0, x[97,2] - y[2] ≤ 0.0, x[97,3] - y[3] ≤ 0.0, x[97,4] - y[4] ≤ 0.0, x[97,5] - y[5] ≤ 0.0, x[97,6] - y[6] ≤ 0.0, x[97,7] - y[7] ≤ 0.0, x[97,8] - y[8] ≤ 0.0, x[97,9] - y[9] ≤ 0.0, x[97,10] - y[10] ≤ 0.0  …  x[97,15] - y[15] ≤ 0.0, x[97,16] - y[16] ≤ 0.0, x[97,17] - y[17] ≤ 0.0, x[97,18] - y[18] ≤ 0.0, x[97,19] - y[19] ≤ 0.0, x[97,20] - y[20] ≤ 0.0, x[97,21] - y[21] ≤ 0.0, x[97,22] - y[22] ≤ 0.0, x[97,23] - y[23] ≤ 0.0, x[97,24] - y[24] ≤ 0.0]
#  [x[98,1] - y[1] ≤ 0.0, x[98,2] - y[2] ≤ 0.0, x[98,3] - y[3] ≤ 0.0, x[98,4] - y[4] ≤ 0.0, x[98,5] - y[5] ≤ 0.0, x[98,6] - y[6] ≤ 0.0, x[98,7] - y[7] ≤ 0.0, x[98,8] - y[8] ≤ 0.0, x[98,9] - y[9] ≤ 0.0, x[98,10] - y[10] ≤ 0.0  …  x[98,15] - y[15] ≤ 0.0, x[98,16] - y[16] ≤ 0.0, x[98,17] - y[17] ≤ 0.0, x[98,18] - y[18] ≤ 0.0, x[98,19] - y[19] ≤ 0.0, x[98,20] - y[20] ≤ 0.0, x[98,21] - y[21] ≤ 0.0, x[98,22] - y[22] ≤ 0.0, x[98,23] - y[23] ≤ 0.0, x[98,24] - y[24] ≤ 0.0]
#  [x[99,1] - y[1] ≤ 0.0, x[99,2] - y[2] ≤ 0.0, x[99,3] - y[3] ≤ 0.0, x[99,4] - y[4] ≤ 0.0, x[99,5] - y[5] ≤ 0.0, x[99,6] - y[6] ≤ 0.0, x[99,7] - y[7] ≤ 0.0, x[99,8] - y[8] ≤ 0.0, x[99,9] - y[9] ≤ 0.0, x[99,10] - y[10] ≤ 0.0  …  x[99,15] - y[15] ≤ 0.0, x[99,16] - y[16] ≤ 0.0, x[99,17] - y[17] ≤ 0.0, x[99,18] - y[18] ≤ 0.0, x[99,19] - y[19] ≤ 0.0, x[99,20] - y[20] ≤ 0.0, x[99,21] - y[21] ≤ 0.0, x[99,22] - y[22] ≤ 0.0, x[99,23] - y[23] ≤ 0.0, x[99,24] - y[24] ≤ 0.0]
#  [x[100,1] - y[1] ≤ 0.0, x[100,2] - y[2] ≤ 0.0, x[100,3] - y[3] ≤ 0.0, x[100,4] - y[4] ≤ 0.0, x[100,5] - y[5] ≤ 0.0, x[100,6] - y[6] ≤ 0.0, x[100,7] - y[7] ≤ 0.0, x[100,8] - y[8] ≤ 0.0, x[100,9] - y[9] ≤ 0.0, x[100,10] - y[10] ≤ 0.0  …  x[100,15] - y[15] ≤ 0.0, x[100,16] - y[16] ≤ 0.0, x[100,17] - y[17] ≤ 0.0, x[100,18] - y[18] ≤ 0.0, x[100,19] - y[19] ≤ 0.0, x[100,20] - y[20] ≤ 0.0, x[100,21] - y[21] ≤ 0.0, x[100,22] - y[22] ≤ 0.0, x[100,23] - y[23] ≤ 0.0, x[100,24] - y[24] ≤ 0.0]

# %%
# Constraint (6)
#@constraint(model, sum(x, dims=1) .<= M * transpose(y))

# %%
optimize!(model)
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (mac64)
# Optimize a model with 7400 rows, 2424 columns and 19200 nonzeros
# Model fingerprint: 0xf256bfc7
# Variable types: 2400 continuous, 24 integer (24 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+04, 2e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.47007e+08 (0.03s)
# Loaded MIP start from previous solve with objective 4.47007e+08
#
# Variable types: 2400 continuous, 24 integer (24 binary)
#
# Root relaxation: cutoff, 189 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4.4701e+08 4.4701e+08  0.00%     -    0s
#
# Explored 0 nodes (189 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 4.47007e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.470065056820e+08, best bound 4.470065056820e+08, gap 0.0000%

# %%
findall(x->x!=-0.0, JuMP.value.(y))
# Out:
# 7-element Array{Int64,1}:
#   5
#   8
#  10
#  12
#  14
#  16
#  24

# %% [markdown]
# A savoir : Buffalo, Houston, Minneapolis, Oakland, Orlando, Paradise CDP, Winston-Salem

# %%
xsum = sum(JuMP.value.(x),dims=1)
xsum[findall(x->x!=0.0,xsum)]
# Out:
# 7-element Array{Float64,1}:
#  19.0
#  15.0
#   9.0
#   8.0
#   9.0
#  20.0
#  20.0
