# %% [markdown]
# <center>
#     <h2> <b> LINMA2450 : Combinatorial optimization </h2>
#     <h1>   <b> Homework 2 - Exercise 2 </h1>
# </center>

# %%
# 0 1 2 4
# 1 0 3 5
# 2 3 0 6
# 4 5 6 0

# i = 1 : (1,2,4)
# i = 2 : (1,3,5)
# i = 3 : (2,3,6)
# i = 4 : (4,5,6)

#ind = [[0 1 2 4]
#       [1 0 3 5]
#       [2 3 0 6]
#       [4 5 6 0]]

#       6
#  1:s ---- 2 
#  6 |      | 6
#    |      |
#    4 ---- 3:t
#       6
    
#h = zeros(6)
#h[1] = 6
#h[2] = 0
#h[3] = 6
#h[4] = 6
#h[5] = 0
#h[6] = 6
    
#s = 1
#t = 3
#min_cut(s,t,h,ind)

# %% [markdown]
# # Preliminaries

# %%
# load data
using DelimitedFiles, LinearAlgebra
dist = readdlm("data26.txt",Int)

V = size(dist)[1]
E = (V-1)*(V) ÷ 2

function index(i,j)
    return (i-2)*(i-1) ÷ 2 + j # Lazy Caterer's sequence + (j-1)
end

ind = zeros(Int, (V,V)) # construct matrix with 2 Floyd's triangle
c = zeros(Int, E) # construct cost vector

for i = 2:V
    for j = 1:i-1
        ind_ij = index(i,j)
        ind[i,j] = ind_ij
        c[ind_ij] = dist[i,j] 
    end
end
ind = ind + transpose(ind)
# Out:
# 26×26 Array{Int64,2}:
#    0    1    2    4    7   11   16   22  …  172  191  211  232  254  277  301
#    1    0    3    5    8   12   17   23     173  192  212  233  255  278  302
#    2    3    0    6    9   13   18   24     174  193  213  234  256  279  303
#    4    5    6    0   10   14   19   25     175  194  214  235  257  280  304
#    7    8    9   10    0   15   20   26     176  195  215  236  258  281  305
#   11   12   13   14   15    0   21   27  …  177  196  216  237  259  282  306
#   16   17   18   19   20   21    0   28     178  197  217  238  260  283  307
#   22   23   24   25   26   27   28    0     179  198  218  239  261  284  308
#   29   30   31   32   33   34   35   36     180  199  219  240  262  285  309
#   37   38   39   40   41   42   43   44     181  200  220  241  263  286  310
#   46   47   48   49   50   51   52   53  …  182  201  221  242  264  287  311
#   56   57   58   59   60   61   62   63     183  202  222  243  265  288  312
#   67   68   69   70   71   72   73   74     184  203  223  244  266  289  313
#   79   80   81   82   83   84   85   86     185  204  224  245  267  290  314
#   92   93   94   95   96   97   98   99     186  205  225  246  268  291  315
#  106  107  108  109  110  111  112  113  …  187  206  226  247  269  292  316
#  121  122  123  124  125  126  127  128     188  207  227  248  270  293  317
#  137  138  139  140  141  142  143  144     189  208  228  249  271  294  318
#  154  155  156  157  158  159  160  161     190  209  229  250  272  295  319
#  172  173  174  175  176  177  178  179       0  210  230  251  273  296  320
#  191  192  193  194  195  196  197  198  …  210    0  231  252  274  297  321
#  211  212  213  214  215  216  217  218     230  231    0  253  275  298  322
#  232  233  234  235  236  237  238  239     251  252  253    0  276  299  323
#  254  255  256  257  258  259  260  261     273  274  275  276    0  300  324
#  277  278  279  280  281  282  283  284     296  297  298  299  300    0  325
#  301  302  303  304  305  306  307  308  …  320  321  322  323  324  325    0

# %%
function min_cut(s,t,h,ind)
    model = Model(with_optimizer(Gurobi.Optimizer))
    set_optimizer_attribute(model, "Presolve", 0)
    set_optimizer_attribute(model, "Heuristics", 0)
    set_optimizer_attribute(model, "Cuts", 0)
    set_silent(model)
    
    E = size(h)[1]
    V = size(ind)[1]
    
    # variables
    @variable(model,0 <= w[1:E])
    @variable(model,u[1:V])
    
    # objective function
    @objective(model, Min, sum(h .* w))
    
    # constraints
    for e = 1:E
        ij = findall(x->(x==e),ind)[1]
        i = ij[1]
        j = ij[2]
        @constraint(model,w[e]>=u[i]-u[j])
        @constraint(model,w[e]>=u[j]-u[i])
    end
    @constraint(model,u[t]-u[s]>=1)
    
    optimize!(model)
    return sum(h.*value.(w)), findall(x->x==0.0,value.(u))
end
# Out:
# min_cut (generic function with 2 methods)

# %%
function delta(S,ind)
    
    V = size(ind)[1]
    E = V*(V-1) ÷ 2 
    
    indices_total = Set{Int}()
    for e = 1:E
        ij = findall(x->(x==e),ind)[1]
        i = ij[1]
        j = ij[2]
                
        if ((i in S) && !(j in S)) || (!(i in S) && (j in S))
            push!(indices_total,e)
        end
    end
    
    return collect(indices_total)
end
# Out:
# delta (generic function with 1 method)

# %% [markdown]
# # Initialization of the LP optimization model

# %%
using Gurobi, JuMP

model = Model(with_optimizer(Gurobi.Optimizer))
set_optimizer_attribute(model, "Presolve", 0)
set_optimizer_attribute(model, "Heuristics", 0)
set_optimizer_attribute(model, "Cuts", 0)
set_silent(model)

# define variables and constraints for the initial LP problem
@variable(model,0 <= x[1:E] <= 1)
@objective(model,Min,sum(c.*x))
for i = 1:V 
    indices = filter!(x -> x ≠ 0,ind[:,i])
    @constraint(model,sum(x[indices]) == 2)
end
# Out:
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only

# %% [markdown]
# # Cut phase : add constraints

# %%
# initialization
optimize!(model)
opt_x = value.(x)

# loop
count=0
count2=0
while true
    t=2
    while t ≠ V+1
        cut_val,S = min_cut(1,t,opt_x,ind)
        count2 = count2+1
        if cut_val < 2
            count = count+1
            ind_cons = delta(S,ind)
            @constraint(model,sum(x[ind_cons]) >= 2)
            optimize!(model)
            opt_x = value.(x)
            break
        end
        t = t+1
    end
    if t==V+1
        break
    end
end

print("\nNumber of min cuts solved : ")
print(count2)
print("\nNumber of constraints added : ")
print(count)
# Out:
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
# Number of min cuts solved : 129
# Number of constraints added : 9

# %% [markdown]
# # Branch phase : IP solution

# %%
# Now we solve the IP problem

#optimize!(model)
#print(objective_value(model))
#print("\n")

#LP_opt_x = value.(x)
## check
#print(LP_opt_x[findall(x->(x ≠ 1.0)&&(x ≠ 0.0),LP_opt_x)])
#print("\n")

for e = 1:E
    @constraint(model, x[e] in JuMP.MOI.ZeroOne())
end

optimize!(model)

print(objective_value(model))
print("\n")

IP_opt_x = value.(x)
# check
print(IP_opt_x[findall(x->(x ≠ 1.0)&&(x ≠ 0.0),IP_opt_x)])
print("\n")
# Out:
# 937.0
# Float64[]

# %% [markdown]
# # Plot

# %%
using GraphRecipes
using Plots

A = zeros(Int,(V,V))
for e = 1:E
    ij = findall(x->x==e,ind)[1]
    i=ij[1]
    j=ij[2]

    A[i,j] = IP_opt_x[e]
    A[j,i] = IP_opt_x[e]
end

graphplot(A,
          markersize = 0.2,
          node_weights = ones(V),
          names = 1:V,
          markercolor = colorant"red",
          curves=false,
          nodeshape=:circle)

# %% [markdown]
# <center>
#     <h1>   <b> Homework 2 - Exercise 3 </h1>
# </center>

# %% [markdown]
# # Preliminaries

# %%
# load data
using DelimitedFiles, LinearAlgebra
dist = readdlm("data26.txt",Int)

V = size(dist)[1]
E = (V-1)*(V) ÷ 2
# Out:
# 325

# %% [markdown]
# # Model

# %%
model = Model(with_optimizer(Gurobi.Optimizer))
set_optimizer_attribute(model, "Presolve", 0)
set_optimizer_attribute(model, "Heuristics", 0)
set_optimizer_attribute(model, "Cuts", 0)

@variable(model, x[1:V,1:V], Bin)
@variable(model, 1 <= u[2:V] <= V-1)
@objective(model, Min, sum(dist.*x))

@constraint(model,diag(x).==0)                         # diag -> 0
@constraint(model,sum(x,dims=1).==1)                   # (6)
@constraint(model,sum(x,dims=2).==1)                   # (7)
@constraint(model,[i = 2:V,j = 2:V],u[i]-u[j]+(V-1)*x[i,j]<=V-2)

optimize!(model)
print(value.(u))
objective_value(model)
# Out:
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
#
# --------------------------------------------
# Warning: your license will expire in 12 days
# --------------------------------------------
#
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (mac64)
# Optimize a model with 703 rows, 701 columns and 3203 nonzeros
# Model fingerprint: 0x3a563778
# Variable types: 25 continuous, 676 integer (676 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [9e+00, 3e+02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Variable types: 25 continuous, 676 integer (676 binary)
#
# Root relaxation: objective 8.354800e+02, 72 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  835.48000    0   46          -  835.48000      -     -    0s
#      0     0  835.48000    0   46          -  835.48000      -     -    0s
#      0     2  835.48000    0   46          -  835.48000      -     -    0s
# *  236   246              48    1214.0000000  839.24000  30.9%   7.1    0s
# *  599   577              24    1212.0000000  842.36000  30.5%   6.1    0s
# *  972   808              46    1202.0000000  851.38000  29.2%   5.9    0s
# * 1579  1130              63    1198.0000000  863.04000  28.0%   6.4    0s
# * 1740  1163              33    1147.0000000  863.04000  24.8%   6.5    0s
# * 2137  1057              35    1075.0000000  863.04000  19.7%   6.7    0s
# * 2813  1159              37    1072.0000000  885.30333  17.4%   6.7    0s
# * 2817  1099              39    1068.0000000  885.30333  17.1%   6.7    0s
# * 2872   957              42    1051.0000000  885.30333  15.8%   6.7    0s
# * 3344  1038              29    1030.0000000  891.32000  13.5%   6.7    0s
# * 3993  1139              36    1009.0000000  903.00000  10.5%   6.6    0s
# * 4534  1486              37    1008.0000000  903.32000  10.4%   6.5    0s
# * 4731  1438              54     988.0000000  906.84000  8.21%   6.4    0s
# * 5281  1538              45     983.0000000  907.17333  7.71%   6.4    0s
# * 5361  1560              40     979.0000000  908.72000  7.18%   6.4    0s
# * 5366  1495              41     975.0000000  908.72000  6.80%   6.4    0s
# * 5706  1569              32     973.0000000  910.56000  6.42%   6.4    0s
# * 5777  1547              35     972.0000000  910.66000  6.31%   6.4    0s
# * 5938  1501              30     969.0000000  910.66000  6.02%   6.4    0s
# * 5983  1210              42     956.0000000  910.72000  4.74%   6.4    0s
# * 6421  1168              31     953.0000000  912.36000  4.26%   6.5    0s
# * 6861   858              32     943.0000000  916.12000  2.85%   6.7    0s
# * 7013   579              29     937.0000000  917.44000  2.09%   6.7    1s
#
# Cutting planes:
#   Learned: 3
#
# Explored 8009 nodes (55008 simplex iterations) in 1.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 937 943 953 ... 983
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.370000000000e+02, best bound 9.370000000000e+02, gap 0.0000%
# 1-dimensional DenseAxisArray{Float64,1,...} with index sets:
#     Dimension 1, 2:26
# And data, a 25-element Array{Float64,1}:
#  25.0
#  24.0
#  23.0
#  21.000000000000004
#  22.0
#  20.000000000000004
#  19.000000000000004
#  18.000000000000004
#  17.0
#  12.0
#  14.0
#  13.0
#  16.0
#  15.000000000000002
#  11.0
#   7.000000000000001
#   8.0
#  10.0
#   9.0
#   6.0
#   5.0
#   3.0
#   2.0
#   1.0
#   4.0
# 937.0

# %%
graphplot(value.(x),
          markersize = 0.2,
          node_weights = ones(V),
          names = 1:V,
          markercolor = colorant"red",
          curves=false,
          nodeshape=:circle)
